# %% [markdown]
# Imported necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset using pandas
df = pd.read_csv('Breast_Cancer.csv')

# %%
# Display the first 4 rows
df.head(4)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# 1            Positive                      14                      5
# 2            Positive                      14                      7
# ...

# %%
# Display the last 4 rows
df.tail(4)
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 4020  Moderately differentiated     2  Regional          46        Positive
# 4021  Moderately differentiated     2  Regional          22        Positive
# 4022  Moderately differentiated     2  Regional          44        Positive
# 4023  Moderately differentiated     2  Regional          30        Positive
#
#      Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 4020            Positive                      14                      8
# 4021            Negative                      11                      3
# ...

# %%
# Get statistical summary of numeric features
df.describe()
# Out:
#                Age   Tumor Size  Regional Node Examined  \
# count  4024.000000  4024.000000             4024.000000
# mean     53.972167    30.473658               14.357107
# std       8.963134    21.119696                8.099675
# min      30.000000     1.000000                1.000000
# 25%      47.000000    16.000000                9.000000
# 50%      54.000000    25.000000               14.000000
# 75%      61.000000    38.000000               19.000000
# max      69.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            4024.000000      4024.000000
# mean                4.158052        71.297962
# std                 5.109331        22.921430
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# 75%                 5.000000        90.000000
# max                46.000000       107.000000

# %%
# This helps us plan if we need to clean or impute any data
df.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
len(df)
# Out:
# 4024

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Display the shape of the dataset: number of rows and columns
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (4024, 16)

# %%
# Display the column names
print("Column names:\n", df.columns.tolist())
# Out:
# Column names:
#  ['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage', 'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status', 'Progesterone Status', 'Regional Node Examined', 'Reginol Node Positive', 'Survival Months', 'Status']

# %%
# Get a concise summary of the dataset including column data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
# Check for total missing values in each column
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
# Optionally, view percentage of missing values
missing_percentage = (missing_values / len(df)) * 100
print("\nPercentage of missing values per column:\n", missing_percentage)
# Out:
# Percentage of missing values per column:
#  Age                       0.0
# Race                      0.0
# Marital Status            0.0
# T Stage                   0.0
# N Stage                   0.0
# 6th Stage                 0.0
# differentiate             0.0
# Grade                     0.0
# A Stage                   0.0
# Tumor Size                0.0
# Estrogen Status           0.0
# Progesterone Status       0.0
# Regional Node Examined    0.0
# Reginol Node Positive     0.0
# Survival Months           0.0
# Status                    0.0
# dtype: float64

# %%
# Helps identify inconsistent labels or typos in categories
categorical_cols = df.select_dtypes(include='object').columns
for col in categorical_cols:
    print(f"Unique values in '{col}':")
    print(df[col].value_counts(), "\n")

# Plot the distribution of the target variable ('Status')
# This helps identify class imbalance
sns.countplot(x='Status', data=df)
plt.title('Distribution of Patient Status (Alive vs Dead)')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()
# Out:
# Unique values in 'Race':
# Race
# White    3413
# Other     320
# Black     291
# Name: count, dtype: int64
#
# Unique values in 'Marital Status':
# Marital Status
# Married      2643
# Single        615
# Divorced      486
# Widowed       235
# Separated      45
# Name: count, dtype: int64
#
# Unique values in 'T Stage ':
# T Stage
# T2    1786
# T1    1603
# T3     533
# T4     102
# Name: count, dtype: int64
#
# Unique values in 'N Stage':
# N Stage
# N1    2732
# N2     820
# N3     472
# Name: count, dtype: int64
#
# Unique values in '6th Stage':
# 6th Stage
# IIA     1305
# IIB     1130
# IIIA    1050
# IIIC     472
# IIIB      67
# Name: count, dtype: int64
#
# Unique values in 'differentiate':
# differentiate
# Moderately differentiated    2351
# Poorly differentiated        1111
# Well differentiated           543
# Undifferentiated               19
# Name: count, dtype: int64
#
# Unique values in 'Grade':
# Grade
# 2                        2351
# ...

# %%
# Check unique values in object (categorical) columns for inconsistencies
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    print(f"\nUnique values in '{col}':\n", df[col].unique())
# Out:
# Unique values in 'Race':
#  ['White' 'Black' 'Other']
#
# Unique values in 'Marital Status':
#  ['Married' 'Divorced' 'Single ' 'Widowed' 'Separated']
#
# Unique values in 'T Stage ':
#  ['T1' 'T2' 'T3' 'T4']
#
# Unique values in 'N Stage':
#  ['N1' 'N2' 'N3']
#
# Unique values in '6th Stage':
#  ['IIA' 'IIIA' 'IIIC' 'IIB' 'IIIB']
#
# Unique values in 'differentiate':
#  ['Poorly differentiated' 'Moderately differentiated' 'Well differentiated'
#  'Undifferentiated']
#
# Unique values in 'Grade':
#  ['3' '2' '1' ' anaplastic; Grade IV']
#
# Unique values in 'A Stage':
#  ['Regional' 'Distant']
#
# Unique values in 'Estrogen Status':
#  ['Positive' 'Negative']
#
# Unique values in 'Progesterone Status':
#  ['Positive' 'Negative']
#
# Unique values in 'Status':
#  ['Alive' 'Dead']

# %%
# Plot boxplots for numerical columns to visually inspect for outliers
numerical_cols = df.select_dtypes(include='number').columns

# Display boxplots one by one for clear visuals
for col in numerical_cols:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot for {col}')
    plt.show()

# %%
# Total missing values in each column
missing_values = df.isnull().sum()

# Percentage of missing values
missing_percentage = (missing_values / len(df)) * 100

# Combine both in one table
missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

# Show only columns with missing data
missing_df = missing_df[missing_df['Missing Values'] > 0]
missing_df
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage (%)]
# Index: []

# %% [markdown]
# None of the values are missing

# %%
# # Identify numerical columns
# num_cols = df.select_dtypes(include=['float64', 'int64']).columns

# # Impute missing values with median
# for col in num_cols:
#     if df[col].isnull().sum() > 0:
#         median_val = df[col].median()
#         df[col].fillna(median_val, inplace=True)
#         print(f"Imputed missing values in '{col}' with median: {median_val}")

# %%
# # Identify categorical columns
# cat_cols = df.select_dtypes(include='object').columns

# # Impute missing values with mode
# for col in cat_cols:
#     if df[col].isnull().sum() > 0:
#         mode_val = df[col].mode()[0]
#         df[col].fillna(mode_val, inplace=True)
#         print(f"Imputed missing values in '{col}' with mode: {mode_val}")

# %%
# Final check
print("Missing values after imputation:\n", df.isnull().sum())
# Out:
# Missing values after imputation:
#  Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
# Select numerical columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Plot boxplots for each numerical column to identify outliers visually
for col in num_cols:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
# Function to detect and optionally remove outliers using IQR
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

# Detect outliers in each numerical column
for col in num_cols:
    outliers = detect_outliers_iqr(df, col)
    print(f"{col}: {len(outliers)} outliers detected")
# Out:
# Age: 0 outliers detected
# Tumor Size: 222 outliers detected
# Regional Node Examined: 72 outliers detected
# Reginol Node Positive: 344 outliers detected
# Survival Months: 18 outliers detected

# %%
# Cap outliers at Q1 - 1.5*IQR and Q3 + 1.5*IQR
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = df[col].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
print(df.columns.tolist())
# Out:
# ['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage', 'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status', 'Progesterone Status', 'Regional Node Examined', 'Reginol Node Positive', 'Survival Months', 'Status']

# %%
# Binary columns - use Label Encoding
label_cols = ['Estrogen Status', 'Progesterone Status', 'Status']

for col in label_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    print(f"{col} encoded as: {dict(zip(le.classes_, le.transform(le.classes_)))}")
# Out:
# Estrogen Status encoded as: {'Negative': np.int64(0), 'Positive': np.int64(1)}
# Progesterone Status encoded as: {'Negative': np.int64(0), 'Positive': np.int64(1)}
# Status encoded as: {'Alive': np.int64(0), 'Dead': np.int64(1)}

# %%
# Encode remaining categorical variables
remaining_cat_cols = ['Race', 'Marital Status', 'N Stage', '6th Stage',
                      'differentiate', 'Grade', 'A Stage']

# Encode each using LabelEncoder
for col in remaining_cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    print(f"{col} encoded.")
# Out:
# Race encoded.
# Marital Status encoded.
# N Stage encoded.
# 6th Stage encoded.
# differentiate encoded.
# Grade encoded.
# A Stage encoded.

# %%
from sklearn.preprocessing import StandardScaler
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
# Make plots display inline in notebooks
# %matplotlib inline

# %%
#Plot the distribution of Age
plt.figure(figsize=(8, 4))
sns.histplot(df['Age'], kde=True, bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Countplot of Survival Status (Alive vs Dead)
plt.figure(figsize=(6, 4))
sns.countplot(x='Status', data=df)
plt.title('Survival Status Counts')
plt.xlabel('Status (0 = Alive, 1 = Dead)')
plt.ylabel('Count')
plt.show()

# %%
# Boxplot of Tumor Size by Survival Status
plt.figure(figsize=(8, 5))
sns.boxplot(x='Status', y='Tumor Size', data=df)
plt.title('Tumor Size vs Survival Status')
plt.xlabel('Status (0 = Alive, 1 = Dead)')
plt.ylabel('Tumor Size')
plt.show()

# %%
#Correlation Heatmap for Numerical Features
plt.figure(figsize=(12, 8))
corr = df.corr(numeric_only=True)  # Avoid future warnings
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Pairplot of Age, Tumor Size, Survival Months vs Status

# %%
# Ensure Status is numeric (0/1)
df['Status'] = df['Status'].replace({'Alive': 0, 'Dead': 1})
df['Status'] = pd.to_numeric(df['Status'], errors='coerce')

# %%
# Select key numeric columns
selected_cols = ['Age', 'Tumor Size', 'Survival Months', 'Status']
eda_pairplot_df = df[selected_cols].dropna()

# %%
# Plot using histograms on diagonal
sns.pairplot(eda_pairplot_df, hue='Status', diag_kind='hist')
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()

# %% [markdown]
# EDA Insights:
# - "Alive" cases outnumber "Dead" ones → class imbalance.
# - Larger Tumor Size is associated with "Dead" outcomes.
# - Survival Months has a strong positive link with survival.
# - Age shows spread across both outcomes — not a direct indicator alone.
# - Heatmap reveals strongest negative correlation between Status and Survival Months.

# %%
# Compute correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# %%
# Correlation with target variable
target_corr = correlation_matrix['Status'].sort_values(ascending=False)
print("Correlation of features with Status:\n")
print(target_corr)
# Out:
# Correlation of features with Status:
#
# Status                    1.000000
# 6th Stage                 0.257636
# N Stage                   0.255772
# Reginol Node Positive     0.249545
# Tumor Size                0.137129
# Grade                     0.134170
# Age                       0.055921
# Regional Node Examined    0.034131
# Marital Status            0.033289
# differentiate            -0.018513
# Race                     -0.050040
# A Stage                  -0.096584
# Progesterone Status      -0.177079
# Estrogen Status          -0.184650
# Survival Months          -0.476556
# Name: Status, dtype: float64

# %%
#  Visualize full correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Full Feature Correlation Heatmap')
plt.show()

# %%
# Select features that have some correlation with Status (e.g., > 0.1 or domain-relevant)
# manually filter based on insight
selected_features = ['Tumor Size', 'Survival Months', 'Age', 'Estrogen Status', 'Progesterone Status']

# Add Status back for modeling
df_selected = df[selected_features + ['Status']]
print("Selected features for modeling:\n", df_selected.columns.tolist())
# Out:
# Selected features for modeling:
#  ['Tumor Size', 'Survival Months', 'Age', 'Estrogen Status', 'Progesterone Status', 'Status']

# %%
# Define selected features and target
selected_features = ['Tumor Size', 'Survival Months', 'Age', 'Estrogen Status', 'Progesterone Status']

# %%
# Ensure target is discrete 0 or 1
df['Status'] = df['Status'].astype(int)

# Extract X and y
X = df[selected_features]
y = df['Status']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict on test set
y_pred = model.predict(X_test)

# Accuracy score
print("Accuracy:", accuracy_score(y_test, y_pred))

# Classification report
print("\n Classification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.8782608695652174
#
#  Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       682
#            2       0.70      0.36      0.47       123
#
#     accuracy                           0.88       805
#    macro avg       0.80      0.66      0.70       805
# weighted avg       0.86      0.88      0.86       805

# %%
# Define features and target again
selected_features = ['Tumor Size', 'Survival Months', 'Age', 'Estrogen Status', 'Progesterone Status']
X = df[selected_features]
y = df['Status'].astype(int)  # Ensure target is integer (0 or 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
# Perform 5-fold cross-validation
model = LogisticRegression(max_iter=1000, random_state=42)
cv_scores = cross_val_score(model, X_scaled, y, cv=5, scoring='accuracy')

# Print average cross-validation accuracy
print("Cross-Validation Accuracy Scores:", cv_scores)
print("Mean Accuracy:", np.mean(cv_scores))
# Out:
# Cross-Validation Accuracy Scores: [0.88695652 0.89440994 0.87826087 0.90062112 0.88432836]
# Mean Accuracy: 0.8889153610827847

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Sample data
selected_features = ['Tumor Size', 'Survival Months', 'Age', 'Estrogen Status', 'Progesterone Status']
X = df[selected_features]
y = df['Status'].astype(int)

# Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split and train model
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Define parameter grid
param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear'],  # 'liblinear' supports l1 and l2 penalties
}
# Grid Search with 5-fold cross-validation
grid = GridSearchCV(LogisticRegression(max_iter=1000), param_grid, cv=5, scoring='accuracy')
grid.fit(X_scaled, y)

# Results
print(" Best Parameters:", grid.best_params_)
print("Best Cross-Validation Score:", grid.best_score_)
# Out:
#  Best Parameters: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Cross-Validation Score: 0.8889153610827847

# %%
import pickle

# Save trained model and scaler
with open("logistic_model.pkl", "wb") as f:
    pickle.dump(model, f)

with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files

# Download model
files.download("logistic_model.pkl")

# Download scaler
files.download("scaler.pkl")

# %%
df['Status'].value_counts()
# Out:
# Status
# 0    3408
# 2     616
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# Convert '2' to 1 for consistency (if 2 = Dead)
df['Status'] = df['Status'].replace(2, 1)

# Separate majority and minority
alive = df[df['Status'] == 0]
dead = df[df['Status'] == 1]

# Upsample the minority class
dead_upsampled = resample(dead,
                          replace=True,        # sample with replacement
                          n_samples=len(alive),# match majority count
                          random_state=42)

# Combine and shuffle
df_balanced = pd.concat([alive, dead_upsampled]).sample(frac=1, random_state=42)

# %%
X = df_balanced[['Tumor Size', 'Survival Months', 'Age', 'Estrogen Status', 'Progesterone Status']]
y = df_balanced['Status']

# %%
if df['Status'].dtype == 'object':
    df['Status'] = df['Status'].map({'Alive': 0, 'Dead': 1})

# %%
print(df['Status'].value_counts())
# Out:
# Status
# 0    3408
# 1     616
# Name: count, dtype: int64
